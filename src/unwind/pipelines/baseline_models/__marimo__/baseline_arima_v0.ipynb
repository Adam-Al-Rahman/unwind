# %%
import polars as pl

from statsforecast import StatsForecast

# %% [markdown]
# # Baseline V0

# %%
import marimo as mo

# %%
from kedro.framework.session import KedroSession
from kedro.framework.startup import bootstrap_project
from pathlib import Path

PROJECT_ROOT = "unwind"
CWD = Path.cwd()
PROJECT_PATH = Path(*CWD.parts[: CWD.parts.index(PROJECT_ROOT) + 1])

bootstrap_project(PROJECT_PATH)

with KedroSession.create(PROJECT_PATH, False) as session:
    context = session.load_context()
    catalog = context.catalog

    ds_train: pl.DataFrame = catalog.load("raw_ingestion.ds_daily_sales")

# %%
ds_train

# %%
StatsForecast.plot(ds_train)
